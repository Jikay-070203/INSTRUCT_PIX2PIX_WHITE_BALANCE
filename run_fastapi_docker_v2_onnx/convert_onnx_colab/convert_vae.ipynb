# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Thư viện :

# %%
# !pip install torch onnx safetensors diffusers transformers
# !pip install torch onnx safetensors
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: onnx in /usr/local/lib/python3.11/dist-packages (1.17.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (0.5.3)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (0.32.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx) (4.25.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers) (8.6.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers) (11.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2025.1.31)

# %%
from huggingface_hub import snapshot_download

# Đường dẫn thư mục lưu trên Google Drive
save_path = "vae"

# Tải toàn bộ thư mục `unet`
snapshot_download(
    repo_id="timbrooks/instruct-pix2pix",
    local_dir=save_path,
    allow_patterns=["vae/*"]  # Chỉ tải thư mục `unet`
)

print(f"✅ Đã tải xong thư mục `vae` vào {save_path}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# diffusion_pytorch_model.fp16.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# diffusion_pytorch_model.fp16.bin:   0%|          | 0.00/167M [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/335M [00:00<?, ?B/s]
# vae%2Fconfig.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# ✅ Đã tải xong thư mục `vae` vào vae

# %%
# !pip install  accelerate
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.3.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.5.1+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.28.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.1.31)

# %%
import torch
import os
import json
from diffusers import AutoencoderKL
from safetensors.torch import load_file

# 🔹 Đường dẫn tới model VAE và config
safetensor_path = "/content/vae/vae/diffusion_pytorch_model.fp16.safetensors"
config_path = "/content/vae/vae/config.json"

# 🔹 Nơi lưu file ONNX
onnx_dir = "/content/drive/MyDrive/Model/vae/model_onnx"
os.makedirs(onnx_dir, exist_ok=True)
onnx_path = os.path.join(onnx_dir, "vae.onnx")

# 🔹 Load config từ file JSON
with open(config_path, "r") as f:
    config = json.load(f)

# 🔹 Tạo mô hình VAE từ config
vae = AutoencoderKL(**config)

# 🔹 Load trọng số từ file safetensors
state_dict = load_file(safetensor_path)

# 🔹 In danh sách key của state_dict (để kiểm tra nếu lỗi tiếp tục xảy ra)
print(" Danh sách key trong state_dict:")
print(list(state_dict.keys())[:20])  # In 20 key đầu tiên để debug

# 🔹 Load lại state_dict với strict=False (bỏ qua key không khớp)
vae.load_state_dict(state_dict, strict=False)

# 🔹 Chuyển mô hình sang chế độ đánh giá
vae.eval()

# 🔹 Tạo tensor input giả lập từ config
batch_size = 1
in_channels = config["in_channels"]
height = config["sample_size"]
width = config["sample_size"]

dummy_input = torch.randn(batch_size, in_channels, height, width, dtype=torch.float32)

# 🔹 Tạo Wrapper để đưa vào ONNX
class VAEWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x):
        return self.model.encode(x).latent_dist.sample()

wrapped_vae = VAEWrapper(vae)

# 🔹 Xuất mô hình VAE sang ONNX
torch.onnx.export(
    wrapped_vae,
    (dummy_input,),
    onnx_path,
    export_params=True,
    opset_version=16,
    do_constant_folding=True,
    input_names=["input"],
    output_names=["latent"],
    dynamic_axes={"input": {0: "batch_size"}, "latent": {0: "batch_size"}}
)

print(f"✅ Convert thành công! Mô hình ONNX VAE đã lưu tại: {onnx_path}")
# Out:
#  Danh sách key trong state_dict:
# ['decoder.conv_in.bias', 'decoder.conv_in.weight', 'decoder.conv_norm_out.bias', 'decoder.conv_norm_out.weight', 'decoder.conv_out.bias', 'decoder.conv_out.weight', 'decoder.mid_block.attentions.0.group_norm.bias', 'decoder.mid_block.attentions.0.group_norm.weight', 'decoder.mid_block.attentions.0.to_k.bias', 'decoder.mid_block.attentions.0.to_k.weight', 'decoder.mid_block.attentions.0.to_out.0.bias', 'decoder.mid_block.attentions.0.to_out.0.weight', 'decoder.mid_block.attentions.0.to_q.bias', 'decoder.mid_block.attentions.0.to_q.weight', 'decoder.mid_block.attentions.0.to_v.bias', 'decoder.mid_block.attentions.0.to_v.weight', 'decoder.mid_block.resnets.0.conv1.bias', 'decoder.mid_block.resnets.0.conv1.weight', 'decoder.mid_block.resnets.0.conv2.bias', 'decoder.mid_block.resnets.0.conv2.weight']
# /usr/local/lib/python3.11/dist-packages/diffusers/models/downsampling.py:136: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /usr/local/lib/python3.11/dist-packages/diffusers/models/downsampling.py:145: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /usr/local/lib/python3.11/dist-packages/torch/onnx/_internal/jit_utils.py:308: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /usr/local/lib/python3.11/dist-packages/torch/onnx/utils.py:663: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /usr/local/lib/python3.11/dist-packages/torch/onnx/utils.py:1186: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at ../torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# ✅ Convert thành công! Mô hình ONNX VAE đã lưu tại: /content/drive/MyDrive/Model/vae/model_onnx/vae.onnx

# %%
import os

onnx_path = "/content/drive/MyDrive/Model/vae/model_onnx/vae.onnx"
print("ONNX File Exists:", os.path.exists(onnx_path))
# Out:
# ONNX File Exists: True

# %%
# !pip install onnxruntime
# Out:
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.11/dist-packages (1.20.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (4.25.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)

# %%
import onnxruntime as ort

onnx_path = "/content/drive/MyDrive/Model/vae/model_onnx/vae.onnx"

# Load ONNX bằng onnxruntime (ít tốn RAM hơn)
session = ort.InferenceSession(onnx_path, providers=["CPUExecutionProvider"])
print("🚀 ONNX model đã load thành công!")
# Out:
# 🚀 ONNX model đã load thành công!

# %%
import os
import glob

onnx_folder = "/content/drive/MyDrive/Model/unet/model_onnx"

# Kiểm tra nếu thư mục tồn tại
if os.path.exists(onnx_folder):
    files = glob.glob(os.path.join(onnx_folder, "*"))  # Lấy tất cả file trong thư mục
    if files:
        for file in files:
            os.remove(file)
            print(f"✅ Đã xóa: {file}")
        print("🚀 Đã xóa tất cả file trong thư mục.")
    else:
        print("⚠️ Không có file nào để xóa.")
else:
    print("⚠️ Thư mục không tồn tại.")
# Out:
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.conv_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.time_embedding.linear_1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.time_embedding.linear_1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.time_embedding.linear_2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.time_embedding.linear_2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.attentions.0.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.attentions.0.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.attentions.1.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.attentions.1.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.resnets.0.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.resnets.0.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.resnets.0.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.resnets.1.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.resnets.1.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.resnets.1.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.0.downsamplers.0.conv.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.attentions.0.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.attentions.0.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.attentions.1.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.attentions.1.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.resnets.0.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.resnets.0.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.resnets.0.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.resnets.0.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.resnets.1.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.resnets.1.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.resnets.1.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.1.downsamplers.0.conv.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.proj_in.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.norm1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.norm1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.norm2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.norm2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.norm3.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.norm3.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.0.proj_out.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.proj_in.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.norm1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.norm1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.norm2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.norm2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.norm3.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.norm3.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.attentions.1.proj_out.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.0.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.0.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.0.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.0.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.0.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.0.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.0.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.0.conv_shortcut.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.1.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.1.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.1.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.1.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.1.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.resnets.1.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.downsamplers.0.conv.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.2.downsamplers.0.conv.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.0.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.0.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.0.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.0.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.0.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.0.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.1.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.1.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.1.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.1.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.1.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.down_blocks.3.resnets.1.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.0.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.0.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.0.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.0.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.0.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.0.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.0.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.0.conv_shortcut.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.1.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.1.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.1.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.1.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.1.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.1.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.1.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.1.conv_shortcut.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.2.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.2.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.2.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.2.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.2.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.2.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.2.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.resnets.2.conv_shortcut.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.upsamplers.0.conv.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.0.upsamplers.0.conv.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.proj_in.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.norm1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.norm1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.norm2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.norm2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.norm3.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.norm3.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.0.proj_out.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.proj_in.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.norm1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.norm1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.norm2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.norm2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.norm3.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.norm3.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.1.proj_out.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.proj_in.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.norm1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.norm1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.norm2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.norm2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_out.0.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.norm3.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.norm3.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.attentions.2.proj_out.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.0.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.0.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.0.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.0.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.0.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.0.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.0.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.0.conv_shortcut.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.1.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.1.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.1.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.1.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.1.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.1.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.1.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.1.conv_shortcut.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.2.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.2.conv1.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.2.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.2.time_emb_proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.2.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.2.conv2.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.2.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.resnets.2.conv_shortcut.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.upsamplers.0.conv.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.1.upsamplers.0.conv.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.0.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.0.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.0.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.1.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.1.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.1.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.2.proj_in.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.2.transformer_blocks.0.ff.net.0.proj.bias
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.attentions.2.proj_out.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets.0.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets.0.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets.0.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets.0.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets.1.conv1.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets.1.time_emb_proj.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets.1.conv2.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets.1.conv_shortcut.weight
# ✅ Đã xóa: /content/drive/MyDrive/Model/unet/model_onnx/model.up_blocks.2.resnets